# %% [markdown]
# <a href="https://colab.research.google.com/github/ps24601/Entity-Extraction/blob/master/notebooks/climatepolicy_data_explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Climate Policy Radar
#
# *   https://climatepolicyradar.org/what-we-do#data
# *   [github data source](https://github.com/climatepolicyradar/open-data)
# *   [github methodology](https://github.com/climatepolicyradar/methodology)

# %%
# !git clone https://github.com/climatepolicyradar/open-data
# Out:
# Cloning into 'open-data'...
# remote: Enumerating objects: 2780, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 2780 (delta 2), reused 10 (delta 2), pack-reused 2768
# Receiving objects: 100% (2780/2780), 46.64 MiB | 11.46 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# Checking out files: 100% (2578/2578), done.

# %%
# create zipped folder and download it.
# !zip -r /content/policyradardata.zip /content/open-data

# %%
import pandas as pd
codebook = "https://github.com/climatepolicyradar/methodology/raw/main/Climate%20Policy%20Radar%20Codebook.xlsx"
codefile = pd.ExcelFile(codebook)

# %%
codefile.sheet_names
# Out:
# ['Regions',
#  'Jurisdictions',
#  'Document categories',
#  'Document types',
#  'Topics',
#  'Sectors',
#  'Instruments']

# %%
# to read all sheets to a map
sheet_to_df_map = {}
for sheet_name in codefile.sheet_names:
    sheet_to_df_map[sheet_name] = codefile.parse(sheet_name)

# %%
sheet_to_df_map['Topics']
# Out:
#                      Values
# 0                Mitigation
# 1                Adaptation
# 2             Loss & Damage
# 3  Disaster Risk Management

# %%
sheet_to_df_map['Sectors']
# Out:
#                       Values
# 0                 Adaptation
# 1                Agriculture
# 2                  Buildings
# 3              Coastal zones
# 4        Cross cutting zones
# 5   Disaster risk management
# 6               Economy-wide
# 7                     Energy
# 8                Environment
# 9                    Finance
# 10                    Health
# 11                  Industry
# 12                    LULUCF
# 13             Public sector
# 14                     Rural
# 15        Social development
# 16                   Tourism
# 17                 Transport
# 18            Transportation
# 19                     Urban
# 20                     Waste
# 21                     Water
# 22                     Other

# %%
sheet_to_df_map['Document categories']
# Out:
#         Values
# 0  Legislative
# 1    Executive

# %%
sheet_to_df_map['Document types']
# Out:
#                   Values
# 0                 Accord
# 1                    Act
# 2            Action plan
# 3                 Agenda
# 4           Constitution
# 5               Decision
# 6                 Decree
# 7                    Law
# 8             Decree law
# 9              Directive
# 10      Discussion paper
# 11                  Edit
# 12           EU decision
# 13          EU directive
# 14         EU regulation
# 15             Framework
# 16                 Order
# 17             Ordinance
# 18                  Plan
# 19                Policy
# 20             Programme
# 21               Roadmap
# 22            Regulation
# 23            Resolution
# 24          Royal decree
# 25                 Rules
# 26  Strategic assessment
# 27              Strategy
# 28                Vision
# 29               Summary
# 30                 Annex
# 31            Assessment
# 32         Press release
# 33                  Bill
# 34              Protocol
# 35              Criteria
# 36             Statement
# 37       Executive order

# %%
import json
import glob
root_path  = '/content/open-data/data/'
country_code = 'AFG'
listof_files = glob.glob(root_path+country_code+'/*')

# %%
listof_files
# Out:
# ['/content/open-data/data/AFG/Energy_Sector_Strategy_1387-1391_(2007_8-2012_3)_11002.json',
#  '/content/open-data/data/AFG/Rural_Renewable_Energy_Policy_(RREP)_10677.json',
#  '/content/open-data/data/AFG/Disaster_management_strategy_(2014-2017)_10686.json',
#  '/content/open-data/data/AFG/National_Comprehensive_Agriculture_Development_Priority_Program_2016_-_2020_12796.json',
#  '/content/open-data/data/AFG/National_Renewable_Energy_Policy_11794.json',
#  '/content/open-data/data/AFG/Law_on_Disaster_Response,_Management_and_Preparedness_11722.json',
#  '/content/open-data/data/AFG/Afghanistan_National_Peace_and_Development_Framework_(ANPDF)_2017-2021_11539.json',
#  '/content/open-data/data/AFG/Legislative_Decree_on_the_Endorsement_of_the_Power_Services_Regulation_Act_11576.json',
#  '/content/open-data/data/AFG/National_Biodiversity_Strategy_and_Action_Plan_11324.json',
#  '/content/open-data/data/AFG/National_Renewable_Energy_Policy_(ANREP)_10323.json']

# %%
file1 = json.load(open(listof_files[-1],'r'))
file1.keys()
# Out:
# dict_keys(['document_instrument_name', 'document_country_english_shortname', 'document_category', 'document_sector_name', 'document_language', 'document_name', 'document_country_code', 'document_hazard_name', 'document_response_name', 'document_type', 'document_framework_name', 'document_region_code', 'document_date', 'document_keyword', 'document_url', 'text_blocks', 'document_description'])

# %%
for key in list(file1.keys())[:-2]:
    print(key)
    print(file1[key],"\n")
# Out:
# document_instrument_name
# ['Education, training and knowledge dissemination|Information', 'International cooperation|Governance', 'Subnational and citizen participation|Governance', 'Processes, plans and strategies|Governance', 'Capacity building|Governance']
#
# document_country_english_shortname
# Afghanistan
#
# document_category
# Policy
#
# document_sector_name
# Energy
#
# document_language
# English
#
# document_name
# National Renewable Energy Policy (ANREP)
#
# document_country_code
# AFG
#
# document_hazard_name
# []
#
# document_response_name
# ['Mitigation', 'Adaptation']
#
# document_type
# Policy
#
# document_framework_name
# []
#
# document_region_code
# South Asia
#
# document_date
# 01/01/2015
#
# document_keyword
# ['Renewables', 'Energy']
#
# document_url
# https://cdn.climatepolicyradar.org/AFG/2015/AFG-2015-01-01-National Renewable Energy Policy (ANREP)_6e7222acbce8e8e11dddb68784a5a9a4.pdf

# %%
from IPython.display import display, Markdown, Latex
display(Markdown(file1['document_description']))
# Out:
# The National Renewable Energy Policy (ANREP) aims to mainstream renewable energy in the national energy sector planning to deploy them in different capacities and through different projects in the country. The policy aims to provide a direction to the renewable energy (REN) sector. The Policy is aligned to the Power Sector Master Plan (PSMP) and the Afghanistan National Development Strategy (ANDS) to set a framework for deployment of REN and it connects with the Rural Renewable Energy Policy (RREP) to ensure an implementation of the policy guidelines in the rural energy sector.&nbsp;<br><br>The Policy sets the following target : to deploy 350-450 MW of REN capacity by 2032, which is equivalent of 10% of the total energy mix of 3500-4500 MW as per the targets of PSMP. To achieve the target, the policy promote the involvement of the private sector, government and non-government organisations and donors.<br><br>The Policy will be implemented in two terms : TERM 1 (2015- 2020) will create the activities for the development of REN sector particularly in the PPP mode; TERM 2 (2021-2032) will deploy REN in full commercialization mode.&nbsp;

# %%
file1['text_blocks']
# Out:
# [{'text_block_id': 'p0_b1', 'text': 'Islamic Republic of Afghanistan'},
#  {'text_block_id': 'p0_b2', 'text': 'Ministry Of Energy and Water'},
#  {'text_block_id': 'p0_b3', 'text': 'RENEWABLE ENERGYPOLICY'},
#  {'text_block_id': 'p2_b4', 'text': 'FOREWORD'},
#  {'text_block_id': 'p2_b5',
#   'text': 'Some salient features of Renewable Energy Policy are:'},
#  {'text_block_id': 'p3_b6',
#   'text': 'Some salient features of Renewable Energy Policy are:\n* Independent power projects (IPPs) for sale of power to the grid only.\n\t* Captive power producers cum grid spillover power projects sells to electricity\n\t* Isolated grid power projects i.e. small, stand-alone projects.\n\t* Isolated grid power projects i.e. small, stand-alone projects.\n It invites investment from the private sector under the following categories of\n\t* Electricity purchase by Utility (ies) from qualifying renewable energy\n\t* This permits  investor in accordance to electricity services law to generate\n\t* This policy allows net metering and billing so that the producer can sell\n\t* The policy delicenses and deregulates small scale power production\n\t* This lays down simplified and transparent principles of tariff determination'},
#  {'text_block_id': 'p4_b24',
#   'text': 'Some salient features of Renewable Energy Policy are:\n* Independent power projects (IPPs) for sale of power to the grid only.\n\t* Captive power producers cum grid spillover power projects sells to electricity\n\t* Isolated grid power projects i.e. small, stand-alone projects.\n\t* Isolated grid power projects i.e. small, stand-alone projects.\n It invites investment from the private sector under the following categories of\n\t* Electricity purchase by Utility (ies) from qualifying renewable energy\n\t* This permits  investor in accordance to electricity services law to generate\n\t* This policy allows net metering and billing so that the producer can sell\n\t* The policy delicenses and deregulates small scale power production\n\t* This lays down simplified and transparent principles of tariff determination\n* This facilitates projects to obtain carbon credits for avoided greenhouse gas\n* This policy strengthens guidelines according to economic strategies for\n* The policy may require an amendment and minor changes based on the'},
#  {'text_block_id': 'p4_b30', 'text': 'Regards'},
#  {'text_block_id': 'p4_b31', 'text': 'Engineer Ali Ahmad Osmani'},
#  {'text_block_id': 'p4_b32', 'text': 'Minister of Energy and Water'},
#  {'text_block_id': 'p5_b33', 'text': 'CONTENTS'},
#  {'text_block_id': 'p6_b34', 'text': 'ACKNOWLEDGMENTS'},
#  {'text_block_id': 'p6_b35',
#   'text': 'ACKNOWLEDGMENTS\n* Deputy Minister of Energy, Ministry of Energy and Water\n* Energy Policy Directorate, Ministry of Energy and Water\n* Renewable Energy Directorate, Ministry of Energy and Water\n* Energy Programming Directorate, Ministry of Energy and Water\n* Inter-Ministerial Commission for Energy Secretariat Team\n* National Area Based Development Program Energy for Rural'},
#  {'text_block_id': 'p6_b47',
#   'text': 'Development,  Ministry of Rural Rehabilitation and Development'},
#  {'text_block_id': 'p6_b48',
#   'text': 'Development,  Ministry of Rural Rehabilitation and Development\n* Da Afghanistan Breshna Sherkat (DABS)\n* Renewable Energy Coordination Committee (RECC)\n* National Environmental Protection Agency (NEPA), Afghanistan\n* United States Assistance International Development (USAID)\n* Institutional Development for Energy in Afghanistan GIZ(IDEA)'},
#  {'text_block_id': 'p7_b58', 'text': 'ABBREVIATIONS'},
#  {'text_block_id': 'p9_b59', 'text': 'EXECUTIVE SUMMARY'},
#  {'text_block_id': 'p10_b60',
#   'text': 'Significant  features of the Policy are:'},
#  {'text_block_id': 'p10_b61',
#   'text': 'Significant  features of the Policy are:\n* The policy identifies high priority sectors with strategic objectives where\n* It supports detailed zone-wise-mapping of REN resources, preparation of\n* The policy facilitates decentralized governance and coordination structure\n* According to this policy, ministry of rural rehabilitation and development (MRRD)\n* It encourages private sector involvement by providing financial incentives and'},
#  {'text_block_id': 'p11_b71',
#   'text': 'Significant  features of the Policy are:\n* The policy identifies high priority sectors with strategic objectives where\n* It supports detailed zone-wise-mapping of REN resources, preparation of\n* The policy facilitates decentralized governance and coordination structure\n* According to this policy, ministry of rural rehabilitation and development (MRRD)\n* It encourages private sector involvement by providing financial incentives and\n* The policy de-licenses REN projects up to 100 kW to be implemented by private\n* It specifies guidelines for setting tariffs for different categories of REN\n* It lays the foundation for setting up â\x80\x9cbasket-fundsâ\x80\x9d for REN projects which would\n* It recognizes the importance of institutional strengthening and possible\n* It mandates the use of standards, quality control, monitoring, knowledge\n* The policy recognizes the need to establish Feed-in-Tariff, Regulated\n* The policy also supports Rules and Regulations, Grid and Mini Grid\n* It encourages and envisages active participation of women on supply and\n* It provides a platform to integrate environment and energy efficiency with REN'},
#  {'text_block_id': 'p12_b89', 'text': '1.0    CONTEXT AND BACKGROUND'},
#  {'text_block_id': 'p12_b90',
#   'text': '1.0    CONTEXT AND BACKGROUND\n* Afghanistan is poised for stability and growth and would require reliable\n* Afghanistan has a total generation capacity of 1450 MW out of which 80% is'},
#  {'text_block_id': 'p13_b94',
#   'text': '1.0    CONTEXT AND BACKGROUND\n* Afghanistan is poised for stability and growth and would require reliable\n* Afghanistan has a total generation capacity of 1450 MW out of which 80% is\n* Even though the per capita CO2 emissions of Afghanistan is among the\n* The PSMP has suggested network planning and expansion in stages wherein\n* The renewable energy sector continues to grow globally. It provided an\n* Afghanistan is endowed with good renewable energy resources. According to\n* The Ministry of Energy and Water (MEW) is the nodal Ministry to plan and'},
#  {'text_block_id': 'p14_b104',
#   'text': '1.0    CONTEXT AND BACKGROUND\n* Afghanistan is poised for stability and growth and would require reliable\n* Afghanistan has a total generation capacity of 1450 MW out of which 80% is\n* Even though the per capita CO2 emissions of Afghanistan is among the\n* The PSMP has suggested network planning and expansion in stages wherein\n* The renewable energy sector continues to grow globally. It provided an\n* Afghanistan is endowed with good renewable energy resources. According to\n* The Ministry of Energy and Water (MEW) is the nodal Ministry to plan and\n* The Renewable Energy Coordination Committee (RECC) with the\n* The renewable energy projects in Afghanistan have so far been supported\n\t* Development of a renewable energy roadmap for the country;\n\t* ARapid Assessment / Gap Analysis, with major components focused on renewable\n\t* A market assessment survey for renewable energy projects, which will include\n\t* A market assessment survey for renewable energy projects, which will include\n The REN sector on account of its potential to support the growth of'},
#  {'text_block_id': 'p15_b116',
#   'text': '1.0    CONTEXT AND BACKGROUND\n* Afghanistan is poised for stability and growth and would require reliable\n* Afghanistan has a total generation capacity of 1450 MW out of which 80% is\n* Even though the per capita CO2 emissions of Afghanistan is among the\n* The PSMP has suggested network planning and expansion in stages wherein\n* The renewable energy sector continues to grow globally. It provided an\n* Afghanistan is endowed with good renewable energy resources. According to\n* The Ministry of Energy and Water (MEW) is the nodal Ministry to plan and\n* The Renewable Energy Coordination Committee (RECC) with the\n* The renewable energy projects in Afghanistan have so far been supported\n\t* Development of a renewable energy roadmap for the country;\n\t* ARapid Assessment / Gap Analysis, with major components focused on renewable\n\t* A market assessment survey for renewable energy projects, which will include\n\t* A market assessment survey for renewable energy projects, which will include\n The REN sector on account of its potential to support the growth of\n* The growing interest of private sector in REN in Afghanistan is corroborated\n* While the donor support for REN is important, there is a scope for improved\n* Against this backdrop, the Afghanistan National Renewable Energy Policy'},
#  {'text_block_id': 'p16_b122', 'text': '2.0 VISION'},
#  {'text_block_id': 'p16_b123', 'text': '2.1    Goals'},
#  {'text_block_id': 'p16_b124',
#   'text': '2.1    Goals\n* The goal of the policy is to Meet the short-term energy needs while\n* Increase the deployment of Renewable Energy Technologies (RETs) in\n* Provide fiscal and non-fiscal incentives to private sector investors an\n* Create mechanisms of involving Government Organization (GOs),\n* Foster international cooperation, particularly with countries in the region\n* Help building safe environment by reduce air pollution, safeguard human'},
#  {'text_block_id': 'p17_b136',
#   'text': '2.1    Goals\n* The goal of the policy is to Meet the short-term energy needs while\n* Increase the deployment of Renewable Energy Technologies (RETs) in\n* Provide fiscal and non-fiscal incentives to private sector investors an\n* Create mechanisms of involving Government Organization (GOs),\n* Foster international cooperation, particularly with countries in the region\n* Help building safe environment by reduce air pollution, safeguard human\n* The policy will synthesize basic principles of the market economy, the political\n<\\li1>'},
#  {'text_block_id': 'p17_b138', 'text': '2.2    Scope'},
#  {'text_block_id': 'p17_b139',
#   'text': '2.2    Scope\n* AREP covers all renewable energy resources and technologies in any capacities\n* Hydro projects up to 3 MW installed capacity, consisting of pico, micro, mini and'},
#  {'text_block_id': 'p17_b143', 'text': '1.'},
#  {'text_block_id': 'p17_b144',
#   'text': 'AREP covers all modes through which REN projects can be developed. This includes grid- connected, mini-grids, hybrids/stand-alone modes.'},
#  {'text_block_id': 'p17_b145', 'text': '2.'},
#  {'text_block_id': 'p17_b146',
#   'text': 'The REN will be used in following applications, but not limited to:'},
#  {'text_block_id': 'p17_b147',
#   'text': "The REN will be used in following applications, but not limited to:\n* Centralized power generation and feeding to the national and private utility's\n* Mini-grids for distributed generation and supply of electricity for\n* nearby loads in industrial, commercial and residential sector under third party"},
#  {'text_block_id': 'p18_b153',
#   'text': "The REN will be used in following applications, but not limited to:\n* Centralized power generation and feeding to the national and private utility's\n* Mini-grids for distributed generation and supply of electricity for\n* nearby loads in industrial, commercial and residential sector under third party\n* captive use in industrial, commercial and residential sector\n* replacement of and/or hybridize with diesel based power generating and\n* rural electrification\n* Stand-alone systems and devices for:\n\t* rural community access for their basic electricity requirements like Roof-top\n<\\li2>\n\t* agricultural and other productive applications in both agricultural and non- agricultural sectors\n\t* usage in rural health centers, street and area lighting, computers in schools,\n\t* telecommunication purposes such as mobile phone towers, television etc.\n\t* strategic establishments such as in the military\n\t* thermal energy for cooking, water heating, steam production, process heat,\n\t* Building energy and green habitats"},
#  {'text_block_id': 'p18_b177', 'text': '2.3     Implementation of AREP'},
#  {'text_block_id': 'p18_b178',
#   'text': 'The AREP will be implemented in two TERMs to achieve the above goals:'},
#  {'text_block_id': 'p18_b179', 'text': '1.'},
#  {'text_block_id': 'p18_b180',
#   'text': 'AREP TERM 1 (2015- 2020) will create and support an atmosphere and activities for the development and growth of REN sector particularly in the PPP mode. It will facilitate a transition from donor supported to private investment driven REN sector with an objective of deploying REN in full commercialization mode during its TERM 2 (2021-2032).'},
#  {'text_block_id': 'p18_b181', 'text': '2.'},
#  {'text_block_id': 'p18_b182',
#   'text': 'The overall goal is to achieve 95% of the total energy mix of 5000 MW to 6000 MW by 2032 translating to a deployment of 4500 MW to 5000 MW of RETs..'},
#  {'text_block_id': 'p18_b183', 'text': '3.'},
#  {'text_block_id': 'p18_b184',
#   'text': 'In order to achieve the above targets, AREPTERM 1 will identify high priority sectors with strategic objectives where deployment of REN projects will be taken up in a programmatic mode. Afew of these high priority sectors are:'},
#  {'text_block_id': 'p19_b185', 'text': 'a.'},
#  {'text_block_id': 'p19_b186',
#   'text': 'Hybridization of existing diesel based mini-grids with REN with a strategic objective of reducing the consumption of diesel and switching to a cleaner option.'},
#  {'text_block_id': 'p19_b187', 'text': 'b.'},
#  {'text_block_id': 'p19_b188',
#   'text': 'Rehabilitation of non-operational/ partly operational REN projects preferably through PPP mode ensuring their socio- economic sustainability.'},
#  {'text_block_id': 'p19_b189', 'text': 'c.'},
#  {'text_block_id': 'p19_b190',
#   'text': 'Provinces which will not be serviced by DABS in near future as per the PSMP.'},
#  {'text_block_id': 'p19_b191', 'text': 'd.'},
#  {'text_block_id': 'p19_b192',
#   'text': 'Distributed generation in economic zones and industrial parks for providing reliable electricity to boost commercial and industrial activities.'},
#  {'text_block_id': 'p19_b193', 'text': 'e.'},
#  {'text_block_id': 'p19_b194',
#   'text': 'Grid-connected projects in Public-Private-Partnership (PPP) mode.'},
#  {'text_block_id': 'p19_b195', 'text': 'f.'},
#  {'text_block_id': 'p19_b196',
#   'text': 'Solar and/or wind pumping with finance facilitation to farmers for increasing the agricultural productivity.'},
#  {'text_block_id': 'p19_b197', 'text': 'g.'},
#  {'text_block_id': 'p19_b198',
#   'text': 'Powering mobile telephone network and other telecommunication infrastructure through REN in remote areas for enhancing safety and security of communities.'},
#  {'text_block_id': 'p19_b199', 'text': 'h.'},
#  {'text_block_id': 'p19_b200',
#   'text': 'Roof-top solar PV projects with or without net metering.'},
#  {'text_block_id': 'p19_b201',
#   'text': 'Roof-top solar PV projects with or without net metering.\n* The RE Project for growth of Agriculture sector to supply energy for\n<\\li1>'},
#  {'text_block_id': 'p19_b203', 'text': 'j.'},
#  {'text_block_id': 'p19_b204',
#   'text': "Biomass energy projects for the rural communities and livestock's."},
#  {'text_block_id': 'p20_b205', 'text': '3.1'},
#  {'text_block_id': 'p20_b206',
#   'text': 'The macro level mapping of REN resources in Afghanistan has been done and is presented in the below table.'},
#  {'text_block_id': 'p20_b207', 'text': '3.2'},
#  {'text_block_id': 'p20_b208',
#   'text': 'In order to facilitate the long-term planning for REN projects, a detailed zone-wise mapping of REN resources would be undertaken and the REN Atlas for Afghanistan will be prepared.'},
#  {'text_block_id': 'p20_b209', 'text': '3.3'},
#  {'text_block_id': 'p20_b210',
#   'text': 'In case of MHP, it should be ensured that the full potential of any identified site be deployed while designing project sizes and capacities.'},
#  {'text_block_id': 'p20_b211', 'text': '3.4'},
#  {'text_block_id': 'p20_b212',
#   'text': 'Guidelines for calculating Levelized Cost of Energy (LCOE) for each RET using global cost trends but customized to Afghanistan, would be prepared to provide the basis for bench marking project costs, preparing budgets, estimating funding requirements and for the purposes of tariff setting for various REN projects.'},
#  {'text_block_id': 'p21_b213', 'text': '3.5'},
#  {'text_block_id': 'p21_b214',
#   'text': 'While designing any REN project, the project sustainability should be ensured by including all costs for operation, maintenance, repair and replacements for at least 10 years of the project life. Further, the project design should also include the institutional mechanism for O&M for the entire project life.'},
#  {'text_block_id': 'p21_b215', 'text': '3.6'},
#  {'text_block_id': 'p21_b216',
#   'text': 'Provincial level master plans will be prepared that should have resource maps, indicative LCOE for each deploy able REN in the province, potential applications and load centers, database of NGOs and their initiatives in REN, and availability of local manufacturers and suppliers. This will help in implementing REN projects in a techno-economically viable manner.'},
#  {'text_block_id': 'p21_b217', 'text': '4.1'},
#  {'text_block_id': 'p21_b218',
#   'text': 'The MEW will have primary responsibility for strategizing, planning and coordinating the implementation of AREP. In TERM 1 a coordination committee headed by Deputy Minister of Energy will be established under framework of MEW through Policy department RE which is one of their tasks to analyses, monitor and implementation of this policy. Secretariat of this Committee will be with RED In TERM 2 after analyzing TERM 1 implementation of this policy will be reviewed.'},
#  {'text_block_id': 'p21_b219', 'text': '4.2'},
#  {'text_block_id': 'p21_b220',
#   'text': 'Given the importance of REN and the role it will play in the socio-economic development of Afghanistan, its development needs to be put on a “fast-track” mode.'},
#  {'text_block_id': 'p21_b221', 'text': '1.2'},
#  {'text_block_id': 'p21_b222',
#   'text': '7:2-In second term according to the evaluation of first term for the implementation of the policy decision will be taken.'},
#  {'text_block_id': 'p21_b223', 'text': '1.3'},
#  {'text_block_id': 'p21_b224',
#   'text': '7:3- keeping in view the importance of the renewable energy social and economic development environmental protection in Afghanistan it is needed to forster the development of the REN sector.'},
#  {'text_block_id': 'p22_b225', 'text': '1:'},
#  {'text_block_id': 'p22_b226_merged',
#   'text': '4 7.4 - The RECC will have members from the MEW, MRRD, MOF, MOE,MAIL, Public health, communication and technology, women affair, education, NEPA, Urban development, ANSA, Municipality of Kabul, private sector DABS, and non-governmental organization among others.'},
#  {'text_block_id': 'p22_b233', 'text': '1.5'},
#  {'text_block_id': 'p22_b234',
#   'text': '7.5 -    The RECC will be developed as coordination committee to coordinate and facilitate the commercialization and growth of REN sector during TERM 2.'},
#  {'text_block_id': 'p22_b235', 'text': '1.6'},
#  {'text_block_id': 'p22_b236',
#   'text': '1.6\n* Assessing REN potential and preparing detailed resource maps.\n* Preparing provincial level REN master plans.\n* Developing technical designs, benchmarks and performance standards.\n* Providing technical assistance and oversight to MRRD, DABS and other GOs\n* Providing technical support to local industry and manufacturers on needs\n* Providing technology specific and other technical inputs to MOF for designing\n* Designing and implementing pilot and demonstration projects that support\n\t* Facilitating technical training, awareness generation and capacity building of\n<\\li2>\n\t\t* Facilitating technical training, awareness generation and capacity building of\n<\\li2>\n Coordinating with donors and other funding organizations to ensure synergy\n\t\t* Be the nodal department in relation to all REN matters.'},
#  {'text_block_id': 'p22_b256',
#   'text': '7.6 - The Renewable Energy Department (RED) of MEW will be the main technical body responsible for, but not limited to the following:'},
#  {'text_block_id': 'p23_b257', 'text': '4.6'},
#  {'text_block_id': 'p23_b258',
#   'text': 'In accordance with the location specific and decentralized nature of REN, a decentralized governance and coordination structure will be set up wherein zonal level bodies known as Zonal Renewable Energy Centre (ZREC) will be created to oversee the implementation of REN in their respective regions. The ZRECs will coordinate with RED of MEW in executing all of the above responsibilities. The ZRECs may be set up at technical and academic institutions, with NGOs that have required capabilities or within any other existing institutional structure such as that of DABS and MRRD. There are already five RED zonal units that have been created in five river basins of Afghanistan and in TERM 2 of AREP, new units will be set up.'},
#  {'text_block_id': 'p23_b259', 'text': '4.7'},
#  {'text_block_id': 'p23_b260',
#   'text': 'Considering the presence of large rural population in Afghanistan that will benefit the most from REN projects, MRRD will support the implementation of rural REN projects of upto one (1MW) MW capacity for providing energy services to various rural development related applications including domestic, productive, health, education, water pumping etc. and will coordinate with other Ministries such as MAIL and MPH. MRRD can implement RE projects beyond the 100 kW limit to utilize the maximum potential of the resource with coordination with MEW according to the Electricity service Law..'},
#  {'text_block_id': 'p23_b261', 'text': '4.8'},
#  {'text_block_id': 'p23_b262',
#   'text': 'Utilities (such as DABS) will be responsible for the operation and maintenance of all grid-connected and mini-grid projects of above 100 kW capacity. However, for O&M of rural REN projects below the capacity of 100 kW, utilities will  coordinate  with  MRRD.'},
#  {'text_block_id': 'p23_b263', 'text': '4.9'},
#  {'text_block_id': 'p23_b264',
#   'text': 'Private sector as IPP, communities and local entrepreneur will be encouraged to develop and manage REN projects on Built-Own-Operate (BOO) basis, and will be governed by appropriate regulations.'},
#  {'text_block_id': 'p23_b265', 'text': '4.10'},
#  {'text_block_id': 'p23_b266',
#   'text': 'Recognizing the catalytic role that NGOs play in implementation of rural community oriented and community focused REN projects, it would be important to put a formal coordination mechanism in place to ensure exchange of information and ideas on one hand, and to avoid overlaps of efforts on the other. Such a mechanism would be institutionalized in TERM 1 which would also include incentivization, facilitation and felicitation of NGO led efforts. This mechanism will be upgraded to a registration –cum- approval platform in TERM 2.'},
#  {'text_block_id': 'p23_b267', 'text': '4.11'},
#  {'text_block_id': 'p23_b268',
#   'text': 'The policy will create formal linkages and cooperation arrangements with organization such as IRENA, SAARC Energy Centre, ECO and others.'},
#  {'text_block_id': 'p24_b269',
#   'text': '5.1     Guidelines for setting up REN projects'},
#  {'text_block_id': 'p24_b270', 'text': '1.'},
#  {'text_block_id': 'p24_b271',
#   'text': 'The main aim of the AREP TERM 1 is to prepare the atmosphere to usher in the commercialization of REN through private sector participation which will be seen in full force during AREP TERM 2. The REN sector has so far been supported mainly by donor funds, which is not a desired scenario for sustaining the REN sector in Afghanistan. It is therefore essential to attract adequate investments from the private sector as the donor and government resources will not have sufficient funds to support the REN sector. However, balancing the requirement of attracting private investments by ensuring appropriate return on investment and that of ensuring reasonability of user charges for the consumers is the critical challenge for the regulatory process. Since the donors supports are not sustainable, in TERM 1 atmosphere for private sector should be paved.'},
#  {'text_block_id': 'p24_b272', 'text': '2.'},
#  {'text_block_id': 'p24_b273',
#   'text': '2.\n* Guidelines for setting up grid-connected REN projects.\n* Guidelines for setting up projects for distributed generation with local grid.\n* Guidelines for setting up off-grid stand-alone projects.\n* Guidelines for setting up roof-top solar projects.'},
#  {'text_block_id': 'p24_b281',
#   'text': 'Therefore, the REN development in TERM 1 will happen under PPP mode wherein a synergy of regulations, incentivization and facilitation will instill the confidence among the private sector to invest in REN projects in Afghanistan. While the entire sector is open to investments from the private sector, in terms of priority, the grid-connected large scale projects are likely to be the first ones to attract private investment, followed by the distributed generation sector and then the off-grid stand-alone sector. This prioritization is on account of the risk perception among the private sector on return of its investment. Accordingly, the AREP TERM 1 will set out following guidelines for attracting private sector investment in REN sector:'},
#  {'text_block_id': 'p25_b282', 'text': '3.'},
#  {'text_block_id': 'p25_b283',
#   'text': 'The guidelines will include, but not limited to the following, as applicable- eligibility criteria; registration process; application process including DPRs and technical designs; clearances and approvals; land acquisition and usage for private, government and community land; grid-connectivity; creation/ use of other infrastructure and facilities such as roads and water; legal, commercial and community related agreements including Power Purchase Agreements (PPAs); safety certifications and quality control procedures; performance guarantees; post commissioning obligations and activities; exit options, both mid-way and at the end of agreed project lifetime; issuing of license (generation, transmission, distribution, operation and maintenance).'},
#  {'text_block_id': 'p25_b284', 'text': '5.2      Financial incentives'},
#  {'text_block_id': 'p25_b285', 'text': 'a)'},
#  {'text_block_id': 'p25_b286',
#   'text': 'Interest subsidies and soft loans (low interest rates, moratorium/ grace  period on repayment, favorable debt-equity ratio).'},
#  {'text_block_id': 'p25_b287', 'text': 'b)'},
#  {'text_block_id': 'p25_b288',
#   'text': 'Customs duty and sales tax exemption for import/ sale of machinery equipment and spare parts meant for the initial installation or for balancing, modernization, maintenance, replacement, or expansion after commissioning of REN projects.'},
#  {'text_block_id': 'p26_b289', 'text': 'c)'},
#  {'text_block_id': 'p26_b290',
#   'text': 'Income tax exemption for the REN project developer for the first 5 years of its commercial operation.'},
#  {'text_block_id': 'p26_b291', 'text': 'd)'},
#  {'text_block_id': 'p26_b292', 'text': 'Land acquisition'},
#  {'text_block_id': 'p26_b293', 'text': 'e)'},
#  {'text_block_id': 'p26_b294',
#   'text': 'Security during project implementation.'},
#  {'text_block_id': 'p26_b295', 'text': 'f)'},
#  {'text_block_id': 'p26_b296',
#   'text': 'Other incentives and rebates that are considered necessary from time to time and on case-by-case basis.'},
#  {'text_block_id': 'p26_b297', 'text': '5.3 Tariffs'},
#  {'text_block_id': 'p26_b298', 'text': '1.'},
#  {'text_block_id': 'p26_b299',
#   'text': "For grid-connected projects- Tariffs for grid connected projects will be set on the 'cost- plus' basis. A firm PPA will be signed between MEW, DABS and Private utility and the project developer mentioning the tariff, including the escalations."},
#  {'text_block_id': 'p26_b300', 'text': '2.'},
#  {'text_block_id': 'p26_b301',
#   'text': "For project having distributed generation and local grid- for distributed  generation projects supplying electricity to third party, tariffs will be decided on mutually negotiated basis between MEW/ utility, the project developer and the consumer. Guiding principle for tariff determination could be 'cost- plus basis'. 'Avoided cost of generation' would be the basis in those regions where conventional generation would probably be significantly more expensive than REN source generation, as fuels have to be transported. A firm PPA will be signed between the project developer and MEW/utility. Explain with example (could be deleted)"},
#  {'text_block_id': 'p26_b302', 'text': '3.'},
#  {'text_block_id': 'p26_b303',
#   'text': 'For REN-diesel hybrid projects- Tariffs will be based on replacement cost of diesel and/or prevailing tariffs whichever is less.'},
#  {'text_block_id': 'p26_b304', 'text': '4.'},
#  {'text_block_id': 'p26_b305',
#   'text': 'For off-grid stand-alone project- Tariffs will be on mutually negated basis with an oversight provided by the ZREC to ensure that vulnerable communities are not burdened with high and unaffordable tariffs for basic and essential electricity services.'},
#  {'text_block_id': 'p26_b306', 'text': '5.4 Wheeling and banking'},
#  {'text_block_id': 'p27_b307', 'text': '5.5      Evacuation of electricit'},
#  {'text_block_id': 'p27_b308', 'text': '5.6 Third party sale'},
#  {'text_block_id': 'p27_b309',
#   'text': '5.7      Land acquisition and leasing'},
#  {'text_block_id': 'p27_b310', 'text': '5.8     Licensing of REN projects'},
#  {'text_block_id': 'p28_b311',
#   'text': '5.9       Renewable Purchase Obligations'},
#  {'text_block_id': 'p28_b312', 'text': '5.10     Regulatory Department'},
#  {'text_block_id': 'p29_b313', 'text': '6.0    FINANCING MECHANISMS FOR REN'},
#  {'text_block_id': 'p29_b314', 'text': '6.1'},
#  {'text_block_id': 'p29_b315',
#   'text': 'In order to support the subsidy requirements and the incentives to the  private sector, adequate funds would be required which will be created by in government budgetary resources and donor funds. These funds will be ring-fenced and managed through mechanism of “basket funds” which will provide the foundation block for setting up a dedicated REN financing institution in future'},
#  {'text_block_id': 'p29_b316', 'text': '6.2'},
#  {'text_block_id': 'p29_b317',
#   'text': 'Global experience has shown the catalytic role played by REN specific financing mechanisms and access to finance, particularly by local entrepreneurs in promoting REN sector. A financial institution dedicated to REN will be set up during TERM 2 that will provide customized financial support to all REN projects to private sector, local enterprises, NGOs, women led REN businesses and others. It will pool in funds from the government resources, as well as from donors and international financial institutions such as the Asian Development Bank, Islamic Development Bank, World Bank etc. The preparation and the work required for setting up this new institution will be taken up in TERM 1.'},
#  {'text_block_id': 'p29_b318', 'text': '6.3'},
#  {'text_block_id': 'p29_b319',
#   'text': 'Considering the fact that REN projects facilitate the adaptation and mitigation measures of climate change, they are eligible for benefitting from several funds dedicated for such purposes. All implementing agencies of REN projects, both in public and private sector, will explore receiving of climate funds to increase the viability of their projects during design and development stage itself.'},
#  {'text_block_id': 'p29_b320', 'text': '7.1'},
#  {'text_block_id': 'p30_b321',
#   'text': 'The REN sector has grown impressively at the global level and new tools and techniques are routinely being used to plan, design, implement and monitor REN projects. While REN is not new to Afghanistan and several projects are operational and under construction, it is prudent to recognize and acknowledge that the capacities, both systemic and human, of Afghan institutions dealing with REN have to be brought at a level where they can absorb and be benefitted from the international development in  technical, managerial, financial and social aspects. Further, it is also important to recognize that existing institutions may need to be reorganized and new institutions may need to be established for effective implementation of AREP in both its terms.'},
#  {'text_block_id': 'p30_b322', 'text': '7.2'},
#  {'text_block_id': 'p30_b323',
#   'text': 'A comprehensive capacity enhancement program at the institutional level would be designed and executed during TERM 1. This will include identification of stakeholders and their current and future role and an assessment of their capacity needs aligned to these roles; design and delivery of generic, specific and customized capacity enhancement program, and their monitoring and assessment frameworks. This would also include identification of partner training institutions, both within and outside of Afghanistan, particularly in the region, creating semi-formal and formal platforms for networking and cross-learning and facilitation of exchange visits for both trainee and trainers.'},
#  {'text_block_id': 'p30_b324', 'text': '7.3'},
#  {'text_block_id': 'p30_b325',
#   'text': 'Networking with other organizations working in the field of REN energy such as ECO, SAARC, IRENA, etc. for transfer of knowledge would be facilitated.'},
#  {'text_block_id': 'p32_b326',
#   'text': '11.0    USER TRAINING AND AWARENESS CREATION'},
#  {'text_block_id': 'p33_b327', 'text': 'GLOSSARY'},
#  {'text_block_id': 'p33_b328', 'text': 'Avoided cost'},
#  {'text_block_id': 'p38_b329', 'text': 'xxiv'},
#  {'text_block_id': 'p38_b330', 'text': 'www.labl.teriin.org'},
#  {'text_block_id': 'p39_b331', 'text': 'ﻦﯿﺣ'},
#  {'text_block_id': 'p39_b332', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p39_b333', 'text': 'زا'},
#  {'text_block_id': 'p39_b334', 'text': 'ﻊﺑﺎﻨﻣ'},
#  {'text_block_id': 'p39_b335', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p39_b336', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p39_b337', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p39_b338', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p39_b339', 'text': 'زا'},
#  {'text_block_id': 'p39_b340', 'text': 'ﺮﻈﻧ'},
#  {'text_block_id': 'p39_b341', 'text': 'يژﻮﻟﺎﻨﮑﺗ'},
#  {'text_block_id': 'p39_b342', 'text': 'و'},
#  {'text_block_id': 'p39_b343', 'text': 'يدﺎـﺼﺘﻗا'},
#  {'text_block_id': 'p39_b344', 'text': 'ﺐﺳﺎﻨﻣ'},
#  {'text_block_id': 'p39_b345', 'text': '،ﺖﺳا'},
#  {'text_block_id': 'p39_b346', 'text': 'ﺪﯾﺎﺑ'},
#  {'text_block_id': 'p39_b347', 'text': 'ﻪﺟﻮﺗ'},
#  {'text_block_id': 'p39_b348', 'text': 'ترﻮـﺻ'},
#  {'text_block_id': 'p39_b349', 'text': 'دﺮﯿﮔ'},
#  {'text_block_id': 'p39_b350', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p39_b351', 'text': 'زا'},
#  {'text_block_id': 'p39_b352', 'text': 'تاﺮﯿﺛﺎﺗ'},
#  {'text_block_id': 'p39_b353', 'text': 'ءﻮـﺳ'},
#  {'text_block_id': 'p39_b354', 'text': 'ﯽﻄﯿﺤﻣ'},
#  {'text_block_id': 'p39_b355', 'text': 'زا'},
#  {'text_block_id': 'p39_b356', 'text': 'ﻞﯿﺒﻗ'},
#  {'text_block_id': 'p39_b357', 'text': 'ﻊﻄﻗ'},
#  {'text_block_id': 'p39_b358', 'text': 'تﻼﮕﻨﺟ'},
#  {'text_block_id': 'p39_b359', 'text': 'يﺮﯿﮔﻮﻠﺟ'},
#  {'text_block_id': 'p39_b360', 'text': 'ﻞﻤﻌﺑ'},
#  {'text_block_id': 'p39_b361', 'text': '.ﺪﯾآ'},
#  {'text_block_id': 'p39_b362', 'text': 'شوﺮﻓ'},
#  {'text_block_id': 'p39_b363', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p39_b364', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p39_b365', 'text': 'ﻂﺳﻮﺗ'},
#  {'text_block_id': 'p39_b366', 'text': 'حاﺮﻃ'},
#  {'text_block_id': 'p39_b367', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p39_b368', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p39_b369', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p39_b370', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p39_b371', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p39_b372', 'text': 'فﺮـــــﺼﻣ'},
#  {'text_block_id': 'p39_b373', 'text': 'نﺎﮔﺪﻨﻨﮐ'},
#  {'text_block_id': 'p39_b374', 'text': 'يداﺮﻔﻧا'},
#  {'text_block_id': 'p39_b375', 'text': 'ﺎﺑ'},
#  {'text_block_id': 'p39_b376', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p39_b377', 'text': 'زا'},
#  {'text_block_id': 'p39_b378', 'text': 'ﺖﺧﺎﺳﺮﯾز'},
#  {'text_block_id': 'p39_b379', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p39_b380', 'text': 'ﻊﯾزﻮﺗ'},
#  {'text_block_id': 'p39_b381', 'text': 'و'},
#  {'text_block_id': 'p39_b382', 'text': 'لﺎﻘﺘﻧا'},
#  {'text_block_id': 'p39_b383', 'text': 'ﮥﮑﺒﺷ'},
#  {'text_block_id': 'p39_b384', 'text': 'نﺎﺘـــــﺴﻧﺎﻐﻓاد'},
#  {'text_block_id': 'p39_b385', 'text': 'ﺎﻨﺷﺮﺑ'},
#  {'text_block_id': 'p39_b386', 'text': 'ﺖﮐﺮﺷ'},
#  {'text_block_id': 'p39_b387', 'text': '.ﺪﺷﺎﺒﯿﻣ'},
#  {'text_block_id': 'p39_b388', 'text': '.'},
#  {'text_block_id': 'p39_b389', 'text': '('},
#  {'text_block_id': 'p39_b390', 'text': 'رﻮﮐﺬﻣ'},
#  {'text_block_id': 'p39_b391', 'text': '.دزادﺮﭙﺑ'},
#  {'text_block_id': 'p39_b392', 'text': 'يژﻮﻟﻮﻨﮑﺗ تﺎﺒﺛ'},
#  {'text_block_id': 'p39_b393', 'text': '-'},
#  {'text_block_id': 'p39_b394', 'text': 'يدﺎﺼﺘﻗا'},
#  {'text_block_id': 'p39_b395', 'text': '–'},
#  {'text_block_id': 'p39_b396', 'text': 'ﯽﻄﯿﺤﻣ'},
#  {'text_block_id': 'p39_b397', 'text': 'ﺐﻧﺎﺟ يﻻﺎﺑ شوﺮﻓ'},
#  {'text_block_id': 'p39_b398', 'text': 'مﻮﺳ'},
#  {'text_block_id': 'p39_b399', 'text': '\ue407ird party sale'},
#  {'text_block_id': 'p39_b400', 'text': 'يﺎﻫ ﻼﺧ ﻞﯾﻮﻤﺗ'},
#  {'text_block_id': 'p39_b401', 'text': 'يﺮﯾﺬﭘ نﺎﮑﻣا'},
#  {'text_block_id': 'p39_b402', 'text': 'Viability gap funding'},
#  {'text_block_id': 'p39_b403_merged_merged_merged_merged_merged_merged',
#   'text': 'يژﺮﻧا شوﺮﻓ و لﺎﻘﺘﻧا قﺮﺑ'},
#  {'text_block_id': 'p40_b405', 'text': '('},
#  {'text_block_id': 'p40_b406', 'text': '('},
#  {'text_block_id': 'p40_b407', 'text': '.'},
#  {'text_block_id': 'p40_b408', 'text': '('},
#  {'text_block_id': 'p40_b409', 'text': '('},
#  {'text_block_id': 'p40_b410', 'text': '.'},
#  {'text_block_id': 'p40_b411', 'text': 'ﻪﯾﺎﻣﺮﺳ'},
#  {'text_block_id': 'p40_b412', 'text': 'يراﺬﮔ'},
#  {'text_block_id': 'p40_b413', 'text': 'ﯽﺻﻮـﺼﺧ'},
#  {'text_block_id': 'p40_b414', 'text': 'ﺖﮐﺮﺷ'},
#  {'text_block_id': 'p40_b415', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b416', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p40_b417', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p40_b418', 'text': 'ﺎﺑ'},
#  {'text_block_id': 'p40_b419', 'text': 'ﺖﯾﺮﯾﺪﻣ'},
#  {'text_block_id': 'p40_b420', 'text': 'ﻊﯾزﻮﺗ'},
#  {'text_block_id': 'p40_b421', 'text': 'و'},
#  {'text_block_id': 'p40_b422', 'text': 'شوﺮﻓ'},
#  {'text_block_id': 'p40_b423', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b424', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p40_b425', 'text': 'وﺮﺳ'},
#  {'text_block_id': 'p40_b426', 'text': 'رﺎﮐ'},
#  {'text_block_id': 'p40_b427', 'text': '.دراد'},
#  {'text_block_id': 'p40_b428', 'text': 'ﻦﯾا'},
#  {'text_block_id': 'p40_b429', 'text': 'ﺖﮐﺮﺷ'},
#  {'text_block_id': 'p40_b430', 'text': 'ﻦﮑﻤﻣ'},
#  {'text_block_id': 'p40_b431', 'text': 'تﺎﺴﯿﺳﺄﺗ'},
#  {'text_block_id': 'p40_b432', 'text': 'ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p40_b433', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b434', 'text': 'دﻮﺧ'},
#  {'text_block_id': 'p40_b435', 'text': 'ار'},
#  {'text_block_id': 'p40_b436', 'text': 'ﻪﺘﺷاد'},
#  {'text_block_id': 'p40_b437', 'text': '.ﺪﺷﺎﺑ'},
#  {'text_block_id': 'p40_b438', 'text': 'دﺎﻬﻧ'},
#  {'text_block_id': 'p40_b439', 'text': 'ﻪﭼ'},
#  {'text_block_id': 'p40_b440', 'text': 'ﻪﻣﺎﻋرﻮﺘﮑﺳرد'},
#  {'text_block_id': 'p40_b441', 'text': 'ﺎﯾ'},
#  {'text_block_id': 'p40_b442', 'text': 'ﯽﺻﻮﺼﺧ'},
#  {'text_block_id': 'p40_b443', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p40_b444', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p40_b445', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b446', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p40_b447', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p40_b448', 'text': 'ار'},
#  {'text_block_id': 'p40_b449', 'text': '،حﺮﻃ'},
#  {'text_block_id': 'p40_b450', 'text': 'ثاﺪﺣا'},
#  {'text_block_id': 'p40_b451', 'text': 'و'},
#  {'text_block_id': 'p40_b452', 'text': 'ﻖﯿﺒﻄﺗ'},
#  {'text_block_id': 'p40_b453', 'text': '.ﺪﻨﮑﯿﻣ'},
#  {'text_block_id': 'p40_b454', 'text': 'مﺰﯿﻧﺎﮑﯿﻣ'},
#  {'text_block_id': 'p40_b455', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p40_b456', 'text': 'ياﺮﺑ'},
#  {'text_block_id': 'p40_b457', 'text': 'ﻖﯾﻮـــــﺸﺗ'},
#  {'text_block_id': 'p40_b458', 'text': 'ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p40_b459', 'text': 'و'},
#  {'text_block_id': 'p40_b460', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p40_b461', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b462', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p40_b463', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p40_b464', 'text': 'درﻮﻣ'},
#  {'text_block_id': 'p40_b465', 'text': 'أﺮﺟا'},
#  {'text_block_id': 'p40_b466', 'text': 'راﺮﻗ'},
#  {'text_block_id': 'p40_b467', 'text': '،دﺮﯿﮕﯿﻣ'},
#  {'text_block_id': 'p40_b468', 'text': 'مﺎﻤﺗ'},
#  {'text_block_id': 'p40_b469', 'text': 'فﺮـﺼﻣ'},
#  {'text_block_id': 'p40_b470', 'text': 'نﺎﮔﺪﻨﻨﮐ'},
#  {'text_block_id': 'p40_b471', 'text': 'ﺎﯾ'},
#  {'text_block_id': 'p40_b472', 'text': 'نﺎﮔﺪﻨﺷوﺮﻓ'},
#  {'text_block_id': 'p40_b473', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b474', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p40_b475', 'text': 'سﺎﺳا'},
#  {'text_block_id': 'p40_b476', 'text': 'هرﺮﻘﻣ'},
#  {'text_block_id': 'p40_b477', 'text': 'ﻒﻠﮑﻣ'},
#  {'text_block_id': 'p40_b478', 'text': 'ﺪﻧا'},
#  {'text_block_id': 'p40_b479', 'text': 'ﺎﺗ'},
#  {'text_block_id': 'p40_b480', 'text': 'يﺪﺼﯿﻓ'},
#  {'text_block_id': 'p40_b481', 'text': 'ﺺﺨﺸﻣ'},
#  {'text_block_id': 'p40_b482', 'text': 'عﻮﻤﺠﻣ'},
#  {'text_block_id': 'p40_b483', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b484', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p40_b485', 'text': 'ﻊﺑﺎﻨﻣ'},
#  {'text_block_id': 'p40_b486', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p40_b487', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p40_b488', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p40_b489', 'text': 'ار'},
#  {'text_block_id': 'p40_b490', 'text': 'يراﺪﯾﺮﺧ'},
#  {'text_block_id': 'p40_b491', 'text': '.ﺪﯾﺎﻤﻧ'},
#  {'text_block_id': 'p40_b492', 'text': 'ماو) ﻪﺿﺮﻗ'},
#  {'text_block_id': 'p40_b493', 'text': '('},
#  {'text_block_id': 'p40_b494', 'text': 'تﺎﻨﯿﻤﻀﺗ'},
#  {'text_block_id': 'p40_b495', 'text': 'و'},
#  {'text_block_id': 'p40_b496', 'text': 'هﺮﯿﻏ'},
#  {'text_block_id': 'p40_b497', 'text': '.ﺪﺷﺎﺒﯿﻣ'},
#  {'text_block_id': 'p40_b498', 'text': '.'},
#  {'text_block_id': 'p40_b499', 'text': '.'},
#  {'text_block_id': 'p40_b500', 'text': 'ﺖﺳد'},
#  {'text_block_id': 'p40_b501', 'text': 'هﺪﻣآ'},
#  {'text_block_id': 'p40_b502', 'text': 'زا'},
#  {'text_block_id': 'p40_b503', 'text': 'ﻖﯾﺮﻃ'},
#  {'text_block_id': 'p40_b504', 'text': 'رﺎﺸﺑآ'},
#  {'text_block_id': 'p40_b505', 'text': 'رد'},
#  {'text_block_id': 'p40_b506', 'text': 'ﻦﯾا'},
#  {'text_block_id': 'p40_b507', 'text': 'يرﻮﮕﺘﮐ'},
#  {'text_block_id': 'p40_b508', 'text': 'ﻞﻣﺎﺷ'},
#  {'text_block_id': 'p40_b509', 'text': 'ﯽﻣ'},
#  {'text_block_id': 'p40_b510', 'text': '.ﺪﻧﻮﺷ'},
#  {'text_block_id': 'p40_b511', 'text': 'يراﺪﯾﺮﺧ ﻪﻣﺎﻨﻘﻓاﻮﺗ'},
#  {'text_block_id': 'p40_b512', 'text': 'قﺮﺑ يژﺮﻧا'},
#  {'text_block_id': 'p40_b513', 'text': 'يزﺎﯿﺘﻣا يﺎﻫ ﻪﻓﺮﻌﺗ'},
#  {'text_block_id': 'p40_b514', 'text': 'Preferential tar'},
#  {'text_block_id': 'p40_b515', 'text': 'i\n s'},
#  {'text_block_id': 'p40_b516', 'text': 'Private utility'},
#  {'text_block_id': 'p40_b517', 'text': 'هژوﺮﭘ حاﺮﻃ'},
#  {'text_block_id': 'p40_b518', 'text': 'Project developer'},
#  {'text_block_id': 'p40_b519', 'text': 'يﺎﻫ ﺖﯿﻔﻠﮑﻣ'},
#  {'text_block_id': 'p40_b520', 'text': 'ﻞﺑﺎﻗ يژﺮﻧا يراﺪﯾﺮﺧ'},
#  {'text_block_id': 'p40_b521', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p40_b522', 'text': 'ﻞﻬﺳ ﻪﺿﺮﻗ'},
#  {'text_block_id': 'p40_b523_merged_merged_merged_merged_merged_merged_merged_merged_merged_merged_merged_merged',
#   'text': 'loan)o\ue415 (S'},
#  {'text_block_id': 'p41_b526', 'text': 'فﺪﻫ'},
#  {'text_block_id': 'p41_b527', 'text': 'نآ'},
#  {'text_block_id': 'p41_b528', 'text': 'ﻢﻫاﺮﻓ'},
#  {'text_block_id': 'p41_b529', 'text': 'يروآ'},
#  {'text_block_id': 'p41_b530', 'text': 'تﺪﻋﺎـــــــﺴﻣ'},
#  {'text_block_id': 'p41_b531', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p41_b532', 'text': 'ﯽﮑﯿﻨﺨﺗ'},
#  {'text_block_id': 'p41_b533', 'text': 'و'},
#  {'text_block_id': 'p41_b534', 'text': 'ﯽﺗرﺎﺠﺗ'},
#  {'text_block_id': 'p41_b535', 'text': 'ياﺮﺑ'},
#  {'text_block_id': 'p41_b536', 'text': 'ﺖﮐﺮﺷ'},
#  {'text_block_id': 'p41_b537', 'text': 'ﺎﻫ'},
#  {'text_block_id': 'p41_b538', 'text': 'و'},
#  {'text_block_id': 'p41_b539', 'text': 'نﺎﻨﭽﻤﻫ'},
#  {'text_block_id': 'p41_b540', 'text': 'داﺮﻓا'},
#  {'text_block_id': 'p41_b541', 'text': 'ياراد'},
#  {'text_block_id': 'p41_b542', 'text': 'تﺎﯾﺮﻈﻧ'},
#  {'text_block_id': 'p41_b543', 'text': 'ﺪﯾﺪﺟ'},
#  {'text_block_id': 'p41_b544', 'text': 'ﯽﺗرﺎﺠﺗ'},
#  {'text_block_id': 'p41_b545', 'text': '.ﺪﺷﺎﺒﯿﻣ'},
#  {'text_block_id': 'p41_b546', 'text': '.'},
#  {'text_block_id': 'p41_b547', 'text': '"'},
#  {'text_block_id': 'p41_b548', 'text': 'ﺺﻟﺎﺧ'},
#  {'text_block_id': 'p41_b549', 'text': '"'},
#  {'text_block_id': 'p41_b550', 'text': '.'},
#  {'text_block_id': 'p41_b551', 'text': 'تﺎﯾﺮﻈﻧ فﺎﺸﮑﻧا'},
#  {'text_block_id': 'p41_b552', 'text': '(تارﺎﮑﺘﺑا) ﺪﯾﺪﺟ'},
#  {'text_block_id': 'p41_b553', 'text': 'ﻞﻘﺘﺴﻣ ةﺪﻨﻨﮐ ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p41_b554', 'text': 'قﺮﺑ يژﺮﻧا'},
#  {'text_block_id': 'p41_b555', 'text': '(Independent Power'},
#  {'text_block_id': 'p41_b556', 'text': 'Producer)'},
#  {'text_block_id': 'p41_b557', 'text': 'ﮏﭼﻮﮐ يﺎﻫ ﻪﮑﺒﺷ'},
#  {'text_block_id': 'p41_b558', 'text': '(Minigrids)'},
#  {'text_block_id': 'p41_b559', 'text': 'مواﺪﺗ يرﺎﺒﺟا ﺖﯿﻌﺿو'},
#  {'text_block_id': 'p41_b560', 'text': '(must-run status)'},
#  {'text_block_id': 'p41_b561', 'text': 'ﻪﻓﺮﻃ ود يﺎﻫﺮﺘﯿﻣ'},
#  {'text_block_id': 'p41_b562', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p41_b563', 'text': '( Net metering)'},
#  {'text_block_id': 'p41_b564_merged_merged_merged_merged_merged_merged',
#   'text': 'ﻪﺑ طﻮﺑﺮﻣ تﺎﻗﻮﺸﻣ تااﺮﺟا'},
#  {'text_block_id': 'p42_b566', 'text': '"'},
#  {'text_block_id': 'p42_b567', 'text': 'ﺖﻇﺎﻔﺣ'},
#  {'text_block_id': 'p42_b568', 'text': '"'},
#  {'text_block_id': 'p42_b569', 'text': '.'},
#  {'text_block_id': 'p42_b570', 'text': '.'},
#  {'text_block_id': 'p42_b571', 'text': ')'},
#  {'text_block_id': 'p42_b572', 'text': 'UNFCC'},
#  {'text_block_id': 'p42_b573', 'text': '('},
#  {'text_block_id': 'p42_b574', 'text': '1992'},
#  {'text_block_id': 'p42_b575', 'text': '.'},
#  {'text_block_id': 'p42_b576', 'text': '.'},
#  {'text_block_id': 'p42_b577', 'text': ')'},
#  {'text_block_id': 'p42_b578', 'text': 'NAMA'},
#  {'text_block_id': 'p42_b579', 'text': '('},
#  {'text_block_id': 'p42_b580', 'text': '.'},
#  {'text_block_id': 'p42_b581', 'text': '.'},
#  {'text_block_id': 'p42_b582', 'text': '.'},
#  {'text_block_id': 'p42_b583', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p42_b584', 'text': 'ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p42_b585', 'text': 'هﺪﺷ'},
#  {'text_block_id': 'p42_b586', 'text': 'ﻂﺳﻮﺗ'},
#  {'text_block_id': 'p42_b587', 'text': 'ﻪﮑﺒﺷ'},
#  {'text_block_id': 'p42_b588', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p42_b589', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p42_b590', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p42_b591', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p42_b592', 'text': 'ﺎﺑ'},
#  {'text_block_id': 'p42_b593', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p42_b594', 'text': 'زا'},
#  {'text_block_id': 'p42_b595', 'text': 'ﻢﺘﺴﯿﺳ'},
#  {'text_block_id': 'p42_b596', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p42_b597', 'text': 'ﺐﺳﺎﻨﻣ'},
#  {'text_block_id': 'p42_b598', 'text': 'ﻦﯿﻌﺗ'},
#  {'text_block_id': 'p42_b599', 'text': 'هﺪﺷ'},
#  {'text_block_id': 'p42_b600', 'text': 'ﺪﯾﺎﺑ'},
#  {'text_block_id': 'p42_b601', 'text': 'ﻼﺑ'},
#  {'text_block_id': 'p42_b602', 'text': 'ﻪﻠﺻﺎﻓ'},
#  {'text_block_id': 'p42_b603', 'text': 'زا'},
#  {'text_block_id': 'p42_b604', 'text': 'ﻞﺤﻣ'},
#  {'text_block_id': 'p42_b605', 'text': 'ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p42_b606', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p42_b607', 'text': 'ﺰﮐﺮﻣ'},
#  {'text_block_id': 'p42_b608', 'text': 'رﺎﺑ'},
#  {'text_block_id': 'p42_b609', 'text': 'ﻪﯿﻠﺨﺗ'},
#  {'text_block_id': 'p42_b610', 'text': 'ﺎﯾ'},
#  {'text_block_id': 'p42_b611', 'text': 'لﺎﻘﺘﻧا'},
#  {'text_block_id': 'p42_b612', 'text': 'ﻪﺘﻓﺎﯾ'},
#  {'text_block_id': 'p42_b613', 'text': 'و'},
#  {'text_block_id': 'p42_b614', 'text': 'ﻊﯾزﻮﺗ'},
#  {'text_block_id': 'p42_b615', 'text': '.ددﺮﮔ'},
#  {'text_block_id': 'p42_b616', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p42_b617', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p42_b618', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p42_b619', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p42_b620', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p42_b621', 'text': 'ًﺎﻤﯿﻘﺘﺴﻣ'},
#  {'text_block_id': 'p42_b622', 'text': 'و'},
# ...
#  {'text_block_id': 'p49_b919', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p49_b920', 'text': 'ﻦﯿﻣﺄﺗ'},
#  {'text_block_id': 'p49_b921', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p49_b922', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p49_b923', 'text': 'نﻮﺌﺼﻣ'},
#  {'text_block_id': 'p49_b924', 'text': 'و'},
#  {'text_block_id': 'p49_b925', 'text': 'لوﺮﺘﻨﮐ'},
#  {'text_block_id': 'p49_b926', 'text': '،ﺖﯿﻔﯿﮐ'},
#  {'text_block_id': 'p49_b927', 'text': 'تﺎﻨﯿﻤـﻀﺗ'},
#  {'text_block_id': 'p49_b928', 'text': '،تااﺮﺟا'},
#  {'text_block_id': 'p49_b929', 'text': 'ﺖﯿﻟﻮﺌـﺴﻣ'},
#  {'text_block_id': 'p49_b930', 'text': 'ﺎﻫ'},
#  {'text_block_id': 'p49_b931', 'text': 'و'},
#  {'text_block_id': 'p49_b932', 'text': 'ﺖﯿﻟﺎﻌﻓ'},
#  {'text_block_id': 'p49_b933', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p49_b934', 'text': 'ﺲﭘ'},
#  {'text_block_id': 'p49_b935', 'text': 'زا'},
#  {'text_block_id': 'p49_b936', 'text': '،ءاﺮﺟا'},
#  {'text_block_id': 'p49_b937', 'text': 'ﻪﻨﯾﺰﮔ'},
#  {'text_block_id': 'p49_b938', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p49_b939', 'text': 'فاﺮــــــﺼﻧا'},
#  {'text_block_id': 'p49_b940', 'text': 'زا'},
#  {'text_block_id': 'p49_b941', 'text': 'ﻪﻣﺎﻨﻘﻓاﻮﺗ'},
#  {'text_block_id': 'p49_b942', 'text': 'رد'},
#  {'text_block_id': 'p49_b943', 'text': 'نﺎﯾﺮﺟ'},
#  {'text_block_id': 'p49_b944', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p49_b945', 'text': 'ﺎﯾ'},
#  {'text_block_id': 'p49_b946', 'text': 'رد'},
#  {'text_block_id': 'p49_b947', 'text': 'ﻢﺘﺧ'},
#  {'text_block_id': 'p49_b948', 'text': 'دﺎﻌﯿﻣ'},
#  {'text_block_id': 'p49_b949', 'text': 'ﻦﯿﯿﻌﺗ'},
#  {'text_block_id': 'p49_b950', 'text': 'ةﺪﺷ'},
#  {'text_block_id': 'p49_b951', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p49_b952', 'text': 'و'},
#  {'text_block_id': 'p49_b953', 'text': 'روﺪﺻ'},
#  {'text_block_id': 'p49_b954', 'text': 'زاﻮﺟ'},
#  {'text_block_id': 'p49_b955', 'text': '،ﺪﯿﻟﻮﺗ)'},
#  {'text_block_id': 'p49_b956', 'text': '،لﺎﻘﺘﻧا'},
#  {'text_block_id': 'p49_b957', 'text': '،ﻊﯾزﻮﺗ'},
#  {'text_block_id': 'p49_b958', 'text': 'هﺮﻬﺑ'},
#  {'text_block_id': 'p49_b959', 'text': 'يرادﺮﺑ'},
#  {'text_block_id': 'p49_b960', 'text': 'و'},
#  {'text_block_id': 'p49_b961', 'text': 'ﻆﻔﺣ'},
#  {'text_block_id': 'p49_b962', 'text': 'و'},
#  {'text_block_id': 'p49_b963', 'text': '.(ﺖﺒﻗاﺮﻣ'},
#  {'text_block_id': 'p49_b964', 'text': '8،2'},
#  {'text_block_id': 'p49_b965', 'text': 'تﺎﻗﻮﺸﻣ'},
#  {'text_block_id': 'p49_b966', 'text': 'ﯽﻟﺎﻣ'},
#  {'text_block_id': 'p49_b967', 'text': 'ﺎﺑ'},
#  {'text_block_id': 'p49_b968', 'text': 'ﻪﺟﻮﺗ'},
#  {'text_block_id': 'p49_b969', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p49_b970', 'text': 'ﻦﯾا'},
#  {'text_block_id': 'p49_b971', 'text': 'ﺖﯿﻌﻗاو'},
#  {'text_block_id': 'p49_b972', 'text': 'ﻪﮐ'},
#  {'text_block_id': 'p49_b973', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p49_b974', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p49_b975', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p49_b976', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p49_b977', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p49_b978', 'text': 'ﺎﺗ'},
#  {'text_block_id': 'p49_b979', 'text': 'نﻮﻨﮐا'},
#  {'text_block_id': 'p49_b980', 'text': 'ًﻼﻣﺎﮐ'},
#  {'text_block_id': 'p49_b981', 'text': 'زا'},
#  {'text_block_id': 'p49_b982', 'text': 'تﺪﻋﺎــﺴﻣ'},
#  {'text_block_id': 'p49_b983', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p49_b984', 'text': 'ﯽﻟﺎﻣ'},
#  {'text_block_id': 'p49_b985', 'text': 'ﻞﯾﻮﻤﺗ'},
#  {'text_block_id': 'p49_b986', 'text': 'نﺎﮔﺪﻨﻨﮐ'},
#  {'text_block_id': 'p49_b987', 'text': 'هﺮﻬﺑ'},
#  {'text_block_id': 'p49_b988', 'text': 'ﺪﻨﻣ'},
#  {'text_block_id': 'p49_b989', 'text': 'هدﻮﺑ'},
#  {'text_block_id': 'p49_b990', 'text': 'و'},
#  {'text_block_id': 'p49_b991', 'text': 'ﺎﺗ'},
#  {'text_block_id': 'p49_b992', 'text': 'زﻮﻨﻫ'},
#  {'text_block_id': 'p49_b993', 'text': 'ردﺎﻗ'},
#  {'text_block_id': 'p49_b994', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p49_b995', 'text': 'ﯽﺋﺎﻔﮐدﻮﺧ'},
#  {'text_block_id': 'p49_b996', 'text': '،ﺖـــﺴﯿﻧ'},
#  {'text_block_id': 'p49_b997', 'text': 'ﻪﺋارا'},
#  {'text_block_id': 'p49_b998', 'text': 'ﺐﺳ'},
#  {'text_block_id': 'p49_b999', 'text': 'يﺪﯾﺎﺳ'},
#  {'text_block_id': 'p49_b1000', 'text': 'ﮏﯾ'},
#  {'text_block_id': 'p49_b1001', 'text': 'ﺮﻣا'},
#  {'text_block_id': 'p49_b1002', 'text': 'يروﺮﺿ'},
#  {'text_block_id': 'p49_b1003', 'text': 'و'},
#  {'text_block_id': 'p49_b1004', 'text': 'ﺮﯿﻏ'},
#  {'text_block_id': 'p49_b1005', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p49_b1006', 'text': 'رﺎﮑﻧا'},
#  {'text_block_id': 'p49_b1007', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p49_b1008', 'text': 'ﺮﻈﻧ'},
#  {'text_block_id': 'p49_b1009', 'text': 'ﯽﻣ'},
#  {'text_block_id': 'p49_b1010', 'text': 'ﺪﺳر'},
#  {'text_block_id': 'p49_b1011', 'text': '.'},
#  {'text_block_id': 'p49_b1012', 'text': '.'},
#  {'text_block_id': 'p49_b1013', 'text': '('},
#  {'text_block_id': 'p49_b1014', 'text': '.'},
#  {'text_block_id': 'p49_b1015', 'text': '.'},
#  {'text_block_id': 'p49_b1016', 'text': '.'},
#  {'text_block_id': 'p49_b1017', 'text': '.'},
#  {'text_block_id': 'p49_b1018', 'text': 'ﺖﯿﻟﺎﻌﻓ'},
#  {'text_block_id': 'p49_b1019', 'text': 'ﯽﺗرﺎﺠﺗ'},
#  {'text_block_id': 'p49_b1020', 'text': '.نآ'},
#  {'text_block_id': 'p49_b1021', 'text': 'د'},
#  {'text_block_id': 'p49_b1022', 'text': 'كﻼﻤﺘﺳا'},
#  {'text_block_id': 'p49_b1023', 'text': '.ﻦﯿﻣز'},
#  {'text_block_id': 'p49_b1024', 'text': '.ﻦﯿﻣز\n'},
#  {'text_block_id': 'p49_b1030_merged_merged_merged_merged_merged_merged_merged_merged',
#   'text': 'ر  ﺮﯾﺎﺳ  تﺎﻗﻮﺸﻣ و ﻪﮑﯿﺗﺎﻔﯿﻔﺨﺗ ًﺎﺘﻗو ًﺎﺘﻗﻮﻓ و ﻪﺑ سﺎﺳا يﺎﯾﺎﻀﻗ ﻪﻧﺎﮔاﺪﺟ يروﺮﺿ ﻪﺘﺷاﺪﻨﭘ ﯽﻣ .ﺪﻧﻮﺷ'},
#  {'text_block_id': 'p50_b1046', 'text': '8،1'},
#  {'text_block_id': 'p50_b1047', 'text': 'دﻮﻤﻨﻫر'},
#  {'text_block_id': 'p50_b1048', 'text': 'ﺎﻫ'},
#  {'text_block_id': 'p50_b1049', 'text': 'ياﺮﺑ'},
#  {'text_block_id': 'p50_b1050', 'text': 'حﺮﻃ'},
#  {'text_block_id': 'p50_b1051', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p50_b1052', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p50_b1053', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p50_b1054', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p50_b1055', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p50_b1056', 'text': '.1'},
#  {'text_block_id': 'p50_b1057', 'text': '.'},
#  {'text_block_id': 'p50_b1058', 'text': '.'},
#  {'text_block_id': 'p50_b1059', 'text': '.2'},
#  {'text_block_id': 'p50_b1060', 'text': '.'},
#  {'text_block_id': 'p50_b1061', 'text': '.'},
#  {'text_block_id': 'p50_b1062', 'text': '.'},
#  {'text_block_id': 'p50_b1063', 'text': ':'},
#  {'text_block_id': 'p50_b1064', 'text': ':'},
#  {'text_block_id': 'p50_b1065', 'text': '/'},
#  {'text_block_id': 'p50_b1066', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p50_b1067_merged_merged_merged_merged_merged',
#   'text': 'ﺮﯾﺎﺳ  ﺎﻨﺑﺮﯾز ﺎﻫ'},
#  {'text_block_id': 'p51_b1070_merged',
#   'text': '. 100 100 100 -11،    8 ()IRENA ()SAARC ()ECO ('},
#  {'text_block_id': 'p52_b1088', 'text': '5.8'},
#  {'text_block_id': 'p52_b1089', 'text': '.1'},
#  {'text_block_id': 'p52_b1090', 'text': '.2'},
#  {'text_block_id': 'p52_b1091', 'text': '.3'},
#  {'text_block_id': 'p52_b1092', 'text': '.4'},
#  {'text_block_id': 'p52_b1093', 'text': '.'},
#  {'text_block_id': 'p52_b1094', 'text': '.5'},
#  {'text_block_id': 'p52_b1095', 'text': '.6'},
#  {'text_block_id': 'p52_b1096', 'text': '.7'},
#  {'text_block_id': 'p52_b1097', 'text': '.'},
#  {'text_block_id': 'p52_b1098', 'text': 'MDG'},
#  {'text_block_id': 'p52_b1099', 'text': '2015'},
#  {'text_block_id': 'p52_b1100', 'text': '.1'},
#  {'text_block_id': 'p52_b1101', 'text': '.2'},
#  {'text_block_id': 'p52_b1102', 'text': '.3'},
#  {'text_block_id': 'p52_b1103', 'text': '.ﺪﻨﮑﯿﻣ'},
#  {'text_block_id': 'p52_b1104_merged_merged_merged_merged', 'text': '. . .'},
#  {'text_block_id': 'p53_b1107', 'text': '.2'},
#  {'text_block_id': 'p53_b1108', 'text': '6'},
#  {'text_block_id': 'p53_b1109', 'text': '.3'},
#  {'text_block_id': 'p53_b1110', 'text': '6'},
#  {'text_block_id': 'p53_b1111', 'text': '.4'},
#  {'text_block_id': 'p53_b1112', 'text': '6'},
#  {'text_block_id': 'p53_b1113', 'text': '.5'},
#  {'text_block_id': 'p53_b1114', 'text': '6'},
#  {'text_block_id': 'p53_b1115', 'text': '0'},
#  {'text_block_id': 'p53_b1116', 'text': '1'},
#  {'text_block_id': 'p53_b1117', 'text': '.6'},
#  {'text_block_id': 'p53_b1118', 'text': '6'},
#  {'text_block_id': 'p53_b1119', 'text': '7'},
#  {'text_block_id': 'p53_b1120',
#   'text': 'ﺪﯾﺪﺠﺗ ﻞﺑﺎﻗ يژﺮﻧا ﯽﺴﯿﻟﺎﭘ ﻖﯿﺒﻄﺗ ياﺮﺑ يرﺎﺘﺧﺎﺳ تﺎﻣاﺪﻗا'},
#  {'text_block_id': 'p53_b1121', 'text': '.1'},
#  {'text_block_id': 'p53_b1122', 'text': '7'},
#  {'text_block_id': 'p53_b1123', 'text': '.'},
#  {'text_block_id': 'p53_b1124', 'text': '.'},
#  {'text_block_id': 'p53_b1125', 'text': '.'},
#  {'text_block_id': 'p53_b1126_merged_merged_merged_merged_merged_merged_merged',
#   'text': '.27 .37 –.47'},
#  {'text_block_id': 'p54_b1133_merged',
#   'text': '.۱ ۶  ﻪــﺸﻘﻧ ﺑادﺮ یر زا ﻊﺑﺎﻨﻣ ﻧاﺮ یژ ﻞﺑﺎﻗ ﺪﯾﺪﺠﺗ رد نﺎﺘـــﺴﻧﺎﻐﻓا ﻪﺑ ﺢﻄﺳ ﮐ نﻼ ﮐﺎﻣ) وﺮ ﯿﻟ (لﻮ ﺻﻮ تر ﮔ ﻪﺘﻓﺮ و دﺪﺟر لو ﻞﯾذ ا ﻪﯿﺋار'},
#  {'text_block_id': 'p54_b1168', 'text': 'ﯽﻨﯿﻤﺨﺗ *'},
#  {'text_block_id': 'p55_b1169', 'text': '.3'},
#  {'text_block_id': 'p55_b1170', 'text': '-'},
#  {'text_block_id': 'p55_b1171', 'text': '/'},
#  {'text_block_id': 'p55_b1172', 'text': '–'},
#  {'text_block_id': 'p55_b1173', 'text': 'ﺖﮐﺮﺷ'},
#  {'text_block_id': 'p55_b1174', 'text': 'هﺮﻬﺑ'},
#  {'text_block_id': 'p55_b1175', 'text': 'ﺪﻨﻣ'},
#  {'text_block_id': 'p55_b1176', 'text': 'هﺪﺷ'},
#  {'text_block_id': 'p55_b1177', 'text': 'ﯽﻤﻧ'},
#  {'text_block_id': 'p55_b1178', 'text': '.ﺪﻨﻧاﻮﺗ'},
#  {'text_block_id': 'p55_b1179', 'text': 'د'},
#  {'text_block_id': 'p55_b1180', 'text': '-'},
#  {'text_block_id': 'p55_b1181', 'text': 'ﺪﺷر'},
#  {'text_block_id': 'p55_b1182', 'text': 'و'},
#  {'text_block_id': 'p55_b1183', 'text': 'ﺖﯾﻮﻘﺗ'},
#  {'text_block_id': 'p55_b1184', 'text': 'ﺖﯿﻟﺎﻌﻓ'},
#  {'text_block_id': 'p55_b1185', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p55_b1186', 'text': 'ﯽﺗرﺎﺠﺗ'},
#  {'text_block_id': 'p55_b1187', 'text': 'و'},
#  {'text_block_id': 'p55_b1188', 'text': '.ﯽﺘﻌﻨﺻ'},
#  {'text_block_id': 'p55_b1189', 'text': '-'},
#  {'text_block_id': 'p55_b1190', 'text': '-ز'},
#  {'text_block_id': 'p55_b1191', 'text': 'ﻦﯿﻣﺄﺗ'},
#  {'text_block_id': 'p55_b1192', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p55_b1193', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p55_b1194', 'text': 'ياﺮﺑ'},
#  {'text_block_id': 'p55_b1195', 'text': 'ﻪﮑﺒﺷ'},
#  {'text_block_id': 'p55_b1196', 'text': 'نﻮﻔﯿﻠﺗ'},
#  {'text_block_id': 'p55_b1197', 'text': 'ﻞﯾﺎﺒﻣ'},
#  {'text_block_id': 'p55_b1198', 'text': 'و'},
#  {'text_block_id': 'p55_b1199', 'text': 'ﺮﯾﺎﺳ'},
#  {'text_block_id': 'p55_b1200', 'text': 'ﺮﯾز'},
#  {'text_block_id': 'p55_b1201', 'text': 'ﺎﻨﺑ'},
#  {'text_block_id': 'p55_b1202', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p55_b1203', 'text': 'ﯽﺗاﺮﺑﺎﺨﻣ'},
#  {'text_block_id': 'p55_b1204', 'text': 'زا'},
#  {'text_block_id': 'p55_b1205', 'text': 'ﻖﯾﺮﻃ'},
#  {'text_block_id': 'p55_b1206', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p55_b1207', 'text': 'ﻞﺑﺎﻗ'},
#  {'text_block_id': 'p55_b1208', 'text': 'ﺪﯾﺪﺠﺗ'},
#  {'text_block_id': 'p55_b1209', 'text': 'رد'},
#  {'text_block_id': 'p55_b1210', 'text': 'ﻖﻃﺎﻨﻣ'},
#  {'text_block_id': 'p55_b1211', 'text': 'رود'},
#  {'text_block_id': 'p55_b1212', 'text': 'ﺖﺳد'},
#  {'text_block_id': 'p55_b1213', 'text': 'ﻪﺑ'},
#  {'text_block_id': 'p55_b1214', 'text': 'رﻮﻈﻨﻣ'},
#  {'text_block_id': 'p55_b1215', 'text': 'ﺶﯾاﺰﻓا'},
#  {'text_block_id': 'p55_b1216', 'text': 'ﺖﯿﻧﻮﺌﺼﻣ'},
#  {'text_block_id': 'p55_b1217', 'text': 'و'},
#  {'text_block_id': 'p55_b1218', 'text': 'ﺖﯿﻨﻣا'},
#  {'text_block_id': 'p55_b1219', 'text': 'نﺎﮔﺪﻨﺷﺎﺑ'},
#  {'text_block_id': 'p55_b1220', 'text': '.ﻞﺤﻣ'},
#  {'text_block_id': 'p55_b1221', 'text': '-س'},
#  {'text_block_id': 'p55_b1222', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p55_b1223', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p55_b1224', 'text': 'هﺎﮕﺘــــــﺳد'},
#  {'text_block_id': 'p55_b1225', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p55_b1226', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p55_b1227', 'text': 'ﯽﺑﺎﺘﻓآ'},
#  {'text_block_id': 'p55_b1228', 'text': '(ﮏﯿﺘﻟوﻮﺗﻮﻓ)'},
#  {'text_block_id': 'p55_b1229', 'text': 'يور'},
#  {'text_block_id': 'p55_b1230', 'text': 'مﺎﺑ'},
#  {'text_block_id': 'p55_b1231', 'text': 'تاﺮﯿﻤﻌﺗ'},
#  {'text_block_id': 'p55_b1232', 'text': 'ياراد'},
#  {'text_block_id': 'p55_b1233', 'text': 'هزاﺪﻧاﺮﺘﯿﻣ'},
#  {'text_block_id': 'p55_b1234', 'text': 'يﺮﯿﮔ'},
#  {'text_block_id': 'p55_b1235_merged_merged_merged_merged_merged',
#   'text': '-ﺺﻟﺎﺧ يﺎﻫﺮﺘﯿﻣ ود ﻪﻓﺮﻃ ﺖﻧ) (ﮓﻨﯾﺮﺘﯿﻣ و ﺎﯾ نوﺪﺑ .نآ -ش  هژوﺮﭘ يﺎﻫ يژﺮﻧا ﻞﺑﺎﻗ ﺪﯾﺪﺠﺗ ياﺮﺑ ﺪـﺷر رﻮﺘﮑـﺳ ﺖﻋارز ﺪﻨﻧﺎﻣ ﻦﯿﻣﺎﺗ يژﺮﻧا قﺮﺑ ياﺮﺑ دﺮــﺳ ﻪﻧﺎﺧ ،ﺎﻫ مرﺎﻓ  يﺎﻫ يراﺪﻟﺎﻣ هﺮﯿﻏو'},
#  {'text_block_id': 'p55_b1267', 'text': '2032'},
#  {'text_block_id': 'p56_b1268', 'text': '.4'},
#  {'text_block_id': 'p56_b1269', 'text': 'i'},
#  {'text_block_id': 'p56_b1270', 'text': 'ii'},
#  {'text_block_id': 'p56_b1271', 'text': '.'},
#  {'text_block_id': 'p56_b1272', 'text': 'هدﺎﻔﺘﺳا'},
#  {'text_block_id': 'p56_b1273', 'text': 'ﻢﯿﻘﺘﺴﻣ'},
#  {'text_block_id': 'p56_b1274', 'text': 'رد'},
#  {'text_block_id': 'p56_b1275', 'text': 'رﻮﺘﮑﺳ'},
#  {'text_block_id': 'p56_b1276', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p56_b1277', 'text': '،ﯽﺘﻌﻨﺻ'},
#  {'text_block_id': 'p56_b1278', 'text': 'ﯽﺗرﺎﺠﺗ'},
#  {'text_block_id': 'p56_b1279', 'text': 'و'},
#  {'text_block_id': 'p56_b1280', 'text': '.ﯽﺸﯾﺎﻫر'},
#  {'text_block_id': 'p56_b1281', 'text': 'iii'},
#  {'text_block_id': 'p56_b1282', 'text': '.'},
#  {'text_block_id': 'p56_b1283', 'text': 'ﺾﯾﻮﻌﺗ'},
#  {'text_block_id': 'p56_b1284', 'text': 'و'},
#  {'text_block_id': 'p56_b1285', 'text': 'ﺎﯾ'},
#  {'text_block_id': 'p56_b1286', 'text': 'ﺐﯿﮐﺮﺗ'},
#  {'text_block_id': 'p56_b1287', 'text': 'ﺎﺑ'},
#  {'text_block_id': 'p56_b1288', 'text': 'هژوﺮﭘ'},
#  {'text_block_id': 'p56_b1289', 'text': 'يﺎﻫ'},
#  {'text_block_id': 'p56_b1290', 'text': 'ﺪﯿﻟﻮﺗ'},
#  {'text_block_id': 'p56_b1291', 'text': 'و'},
#  {'text_block_id': 'p56_b1292', 'text': 'ﻦﯿﻣﺄﺗ'},
#  {'text_block_id': 'p56_b1293', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p56_b1294', 'text': 'قﺮﺑ'},
#  {'text_block_id': 'p56_b1295', 'text': '.ﯽﻟﺰﯾد'},
#  {'text_block_id': 'p56_b1296', 'text': 'iv'},
#  {'text_block_id': 'p56_b1297', 'text': '.'},
#  {'text_block_id': 'p56_b1298', 'text': 'ﻖﻃﺎﻨﻣ'},
#  {'text_block_id': 'p56_b1299', 'text': '.ﯽﺋﺎﺘﺳور'},
#  {'text_block_id': 'p56_b1300', 'text': ':'},
#  {'text_block_id': 'p56_b1301', 'text': 'i'},
#  {'text_block_id': 'p56_b1302', 'text': '.'},
#  {'text_block_id': 'p56_b1303', 'text': 'ﻪﻧﺎﺧ'},
#  {'text_block_id': 'p56_b1304', 'text': '.ﺎﻫ'},
#  {'text_block_id': 'p56_b1305', 'text': 'ii'},
#  {'text_block_id': 'p56_b1306', 'text': '.'},
#  {'text_block_id': 'p56_b1307', 'text': 'iii'},
#  {'text_block_id': 'p56_b1308', 'text': '.'},
#  {'text_block_id': 'p56_b1309', 'text': '،ﯽﻧﺪﯿﻣﺎﺷآ'},
#  {'text_block_id': 'p56_b1310', 'text': 'ﺰﮐاﺮﻣ'},
#  {'text_block_id': 'p56_b1311', 'text': 'هﺎﻓر'},
#  {'text_block_id': 'p56_b1312', 'text': 'ﯽﻋﺎﻤﺘﺟا'},
#  {'text_block_id': 'p56_b1313', 'text': 'و'},
#  {'text_block_id': 'p56_b1314', 'text': '.هﺮﯿﻏ'},
#  {'text_block_id': 'p56_b1315', 'text': 'iv'},
#  {'text_block_id': 'p56_b1316', 'text': '.'},
#  {'text_block_id': 'p56_b1317', 'text': 'v'},
#  {'text_block_id': 'p56_b1318', 'text': '.'},
#  {'text_block_id': 'p56_b1319', 'text': 'vi'},
#  {'text_block_id': 'p56_b1320', 'text': '.'},
#  {'text_block_id': 'p56_b1321', 'text': '.د'},
#  {'text_block_id': 'p56_b1322', 'text': 'يژﺮﻧا'},
#  {'text_block_id': 'p56_b1323', 'text': 'رد'},
#  {'text_block_id': 'p56_b1324', 'text': 'نﺎﻤﺘﺧﺎﺳ'},
#  {'text_block_id': 'p56_b1325', 'text': 'تﻼﺤﻣو'},
#  {'text_block_id': 'p56_b1326', 'text': 'ﯽﻧﻮﮑﺴﻣ'},
#  {'text_block_id': 'p56_b1327', 'text': '.ﺰﺒﺳ'},
#  {'text_block_id': 'p56_b1328', 'text': '5'},
#  {'text_block_id': 'p56_b1329', 'text': 'ﺪﯾﺪﺠﺗ ﻞﺑﺎﻗ يژﺮﻧا ﯽﺴﯿﻟﺎﭘ ﻖﯿﺒﻄﺗ'},
#  {'text_block_id': 'p56_b1330', 'text': '1.6'},
#  {'text_block_id': 'p56_b1331', 'text': '.1'},
#  {'text_block_id': 'p56_b1332', 'text': '2015)'},
#  {'text_block_id': 'p56_b1333', 'text': 'ﯽﻟا'},
#  {'text_block_id': 'p56_b1334', 'text': '(2020'},
#  {'text_block_id': 'p56_b1335', 'text': '.'},
#  {'text_block_id': 'p56_b1336', 'text': '2021)'},
#  {'text_block_id': 'p56_b1337', 'text': 'ﯽﻟا'},
#  {'text_block_id': 'p56_b1338', 'text': '(2032'},
#  {'text_block_id': 'p56_b1339', 'text': 'ﺪﻋﺎﺴﻣ'},
#  {'text_block_id': 'p56_b1340', 'text': 'ﯽﻣ'},
#  {'text_block_id': 'p56_b1341', 'text': '.دزﺎﺳ'},
#  {'text_block_id': 'p56_b1342', 'text': '.2'},
#  {'text_block_id': 'p56_b1343', 'text': '95'},
#  {'text_block_id': 'p56_b1344', 'text': '6000'},
#  {'text_block_id': 'p56_b1345', 'text': '2032'},
#  ...]

# %% [markdown]
# #
